# %% [markdown]
# ## Setup
#
# Import necessary libraries for this example.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Loading
#
# Load sample data from the CSV file.

# %%
# Load sample data
df = pd.read_csv('sample-data.csv')
df.head()

# %% [markdown]
# ## Data Analysis
#
# Basic statistics of the dataset.

# %%
# Display basic statistics
df.describe()

# %% [markdown]
# ## Results
#
# Example of how to display results in a notebook.

# %%
print(f"Total rows: {len(df)}")
print(f"Total columns: {len(df.columns)}")
